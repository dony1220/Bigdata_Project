# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import matplotlib.font_manager as fm



df = pd.read_excel(r"/content/drive/MyDrive/Colab Notebooks/천재교육 프로젝트/미니프로젝트-쇼핑몰 실습데이터.xlsx")
df
# Out:
#                    주문번호    업체명                                  상품명    제조사  \
# 0       191213170236874     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 1       191216100347429     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 2       191216100347429     지니             eHBM셀파수학교실 삼색볼펜-1세트 50개입     HB
# 3       191216173241622     지니          eHBM셀파수학교실 회원용 리플렛-1세트 50권입     HB
# 4       191216173241622     지니              eHBM셀파수학교실-학습계통도(중등 5종)     HB
# ...                 ...    ...                                  ...    ...
# 218596  221108104041264  에이스디포               [스마트 HBE*초도] 입체 액자형 현판  에이스디포
# 218597  221108104041264  에이스디포                  [스마트 HBE*초도] 아크릴 사인     HB
# 218598  221108104536307  에이스디포                     [스마트 HBM] 아크릴 사인     HB
# 218599  221108104735216   다우기술                [스타벅스] 아이스 카페 아메리카노 T   스타벅스
# 218600  221108105148171   다우기술  [특별한 크리스마스] 2차-신세계 상품권 모바일 교환권-1만원권    신세계
#
#         주문수량    판매금액   결제방법                주문일자  처리상태 초도상품 제작문구 내역 할부기간
# 0          1    5000   신용카드 2019-12-13 17:03:37  구매확정    N     NaN  NaN
# 1          1    5000   신용카드 2019-12-16 10:04:50  구매확정    N     NaN  NaN
# 2          3   67500   신용카드 2019-12-16 10:04:50  구매확정    N     NaN  NaN
# 3          2   30000   신용카드 2019-12-16 17:33:43  구매확정    N     NaN  NaN
# 4          1     750   신용카드 2019-12-16 17:33:43  구매확정    N     NaN  NaN
# ...      ...     ...    ...                 ...   ...  ...     ...  ...
# 218596     1   35000   웰컴마일 2022-11-08 10:38:21  결제완료    Y     NaN  NaN
# 218597     1   26900   웰컴마일 2022-11-08 10:38:21  결제완료    Y     NaN  NaN
# 218598     1   26900  신 + 포 2022-11-08 10:43:15  배송준비    N     NaN  NaN
# 218599     1    4050    포인트 2022-11-08 10:45:14  배송완료    N     NaN  NaN
# 218600    17  161500   신용카드 2022-11-08 10:49:28  배송완료    N     NaN  NaN
#
# [218601 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# 주문번호            0
# 업체명             1
# 상품명            86
# 제조사         27165
# 주문수량            0
# 판매금액            0
# 결제방법           14
# 주문일자            0
# 처리상태            0
# 초도상품            0
# 제작문구 내역    212567
# 할부기간       216674
# dtype: int64

# %%
df.drop(['제작문구 내역','할부기간'],axis=1, inplace=True)
df
# Out:
#                    주문번호    업체명                                  상품명    제조사  \
# 0       191213170236874     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 1       191216100347429     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 2       191216100347429     지니             eHBM셀파수학교실 삼색볼펜-1세트 50개입     HB
# 3       191216173241622     지니          eHBM셀파수학교실 회원용 리플렛-1세트 50권입     HB
# 4       191216173241622     지니              eHBM셀파수학교실-학습계통도(중등 5종)     HB
# ...                 ...    ...                                  ...    ...
# 218596  221108104041264  에이스디포               [스마트 HBE*초도] 입체 액자형 현판  에이스디포
# 218597  221108104041264  에이스디포                  [스마트 HBE*초도] 아크릴 사인     HB
# 218598  221108104536307  에이스디포                     [스마트 HBM] 아크릴 사인     HB
# 218599  221108104735216   다우기술                [스타벅스] 아이스 카페 아메리카노 T   스타벅스
# 218600  221108105148171   다우기술  [특별한 크리스마스] 2차-신세계 상품권 모바일 교환권-1만원권    신세계
#
#         주문수량    판매금액   결제방법                주문일자  처리상태 초도상품
# 0          1    5000   신용카드 2019-12-13 17:03:37  구매확정    N
# 1          1    5000   신용카드 2019-12-16 10:04:50  구매확정    N
# 2          3   67500   신용카드 2019-12-16 10:04:50  구매확정    N
# 3          2   30000   신용카드 2019-12-16 17:33:43  구매확정    N
# 4          1     750   신용카드 2019-12-16 17:33:43  구매확정    N
# ...      ...     ...    ...                 ...   ...  ...
# 218596     1   35000   웰컴마일 2022-11-08 10:38:21  결제완료    Y
# 218597     1   26900   웰컴마일 2022-11-08 10:38:21  결제완료    Y
# 218598     1   26900  신 + 포 2022-11-08 10:43:15  배송준비    N
# 218599     1    4050    포인트 2022-11-08 10:45:14  배송완료    N
# 218600    17  161500   신용카드 2022-11-08 10:49:28  배송완료    N
#
# [218601 rows x 10 columns]

# %%
df['초도상품'].value_counts()
# Out:
# N    202598
# Y     16003
# Name: 초도상품, dtype: int64

# %%
df['업체명'].value_counts()
# Out:
# 다우기술        85553
# 지니          61835
# 쥬크박스        18661
# 에이스디포        8388
# 오피스퀵         7173
#             ...
# 리체              4
# 프린피아            4
# 링커블테크놀러지        3
# 한샘글로벌           3
# 에어인             1
# Name: 업체명, Length: 89, dtype: int64

# %%
#제조사랑, 상품명, 업체명, 결제방법이 nan값인게 있는데, 이거는 제거해주고 분석해도 충분할 듯?
df.isnull().sum()
# Out:
# 주문번호        0
# 업체명         1
# 상품명        86
# 제조사     27165
# 주문수량        0
# 판매금액        0
# 결제방법       14
# 주문일자        0
# 처리상태        0
# 초도상품        0
# dtype: int64

# %%
df.dtypes
# Out:
# 주문번호             int64
# 업체명             object
# 상품명             object
# 제조사             object
# 주문수량             int64
# 판매금액             int64
# 결제방법            object
# 주문일자    datetime64[ns]
# 처리상태            object
# 초도상품            object
# dtype: object

# %%
df['Month'] = df['주문일자'].dt.month
df
# Out:
#                    주문번호    업체명                                  상품명    제조사  \
# 0       191213170236874     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 1       191216100347429     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 2       191216100347429     지니             eHBM셀파수학교실 삼색볼펜-1세트 50개입     HB
# 3       191216173241622     지니          eHBM셀파수학교실 회원용 리플렛-1세트 50권입     HB
# 4       191216173241622     지니              eHBM셀파수학교실-학습계통도(중등 5종)     HB
# ...                 ...    ...                                  ...    ...
# 218596  221108104041264  에이스디포               [스마트 HBE*초도] 입체 액자형 현판  에이스디포
# 218597  221108104041264  에이스디포                  [스마트 HBE*초도] 아크릴 사인     HB
# 218598  221108104536307  에이스디포                     [스마트 HBM] 아크릴 사인     HB
# 218599  221108104735216   다우기술                [스타벅스] 아이스 카페 아메리카노 T   스타벅스
# 218600  221108105148171   다우기술  [특별한 크리스마스] 2차-신세계 상품권 모바일 교환권-1만원권    신세계
#
#         주문수량    판매금액   결제방법                주문일자  처리상태 초도상품  Month
# 0          1    5000   신용카드 2019-12-13 17:03:37  구매확정    N     12
# 1          1    5000   신용카드 2019-12-16 10:04:50  구매확정    N     12
# 2          3   67500   신용카드 2019-12-16 10:04:50  구매확정    N     12
# 3          2   30000   신용카드 2019-12-16 17:33:43  구매확정    N     12
# 4          1     750   신용카드 2019-12-16 17:33:43  구매확정    N     12
# ...      ...     ...    ...                 ...   ...  ...    ...
# 218596     1   35000   웰컴마일 2022-11-08 10:38:21  결제완료    Y     11
# 218597     1   26900   웰컴마일 2022-11-08 10:38:21  결제완료    Y     11
# 218598     1   26900  신 + 포 2022-11-08 10:43:15  배송준비    N     11
# 218599     1    4050    포인트 2022-11-08 10:45:14  배송완료    N     11
# 218600    17  161500   신용카드 2022-11-08 10:49:28  배송완료    N     11
#
# [218601 rows x 11 columns]

# %%
df['Year'] = df['주문일자'].dt.year
df
# Out:
#                    주문번호    업체명                                  상품명    제조사  \
# 0       191213170236874     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 1       191216100347429     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 2       191216100347429     지니             eHBM셀파수학교실 삼색볼펜-1세트 50개입     HB
# 3       191216173241622     지니          eHBM셀파수학교실 회원용 리플렛-1세트 50권입     HB
# 4       191216173241622     지니              eHBM셀파수학교실-학습계통도(중등 5종)     HB
# ...                 ...    ...                                  ...    ...
# 218596  221108104041264  에이스디포               [스마트 HBE*초도] 입체 액자형 현판  에이스디포
# 218597  221108104041264  에이스디포                  [스마트 HBE*초도] 아크릴 사인     HB
# 218598  221108104536307  에이스디포                     [스마트 HBM] 아크릴 사인     HB
# 218599  221108104735216   다우기술                [스타벅스] 아이스 카페 아메리카노 T   스타벅스
# 218600  221108105148171   다우기술  [특별한 크리스마스] 2차-신세계 상품권 모바일 교환권-1만원권    신세계
#
#         주문수량    판매금액   결제방법                주문일자  처리상태 초도상품  Month  Year
# 0          1    5000   신용카드 2019-12-13 17:03:37  구매확정    N     12  2019
# 1          1    5000   신용카드 2019-12-16 10:04:50  구매확정    N     12  2019
# 2          3   67500   신용카드 2019-12-16 10:04:50  구매확정    N     12  2019
# 3          2   30000   신용카드 2019-12-16 17:33:43  구매확정    N     12  2019
# 4          1     750   신용카드 2019-12-16 17:33:43  구매확정    N     12  2019
# ...      ...     ...    ...                 ...   ...  ...    ...   ...
# 218596     1   35000   웰컴마일 2022-11-08 10:38:21  결제완료    Y     11  2022
# 218597     1   26900   웰컴마일 2022-11-08 10:38:21  결제완료    Y     11  2022
# 218598     1   26900  신 + 포 2022-11-08 10:43:15  배송준비    N     11  2022
# 218599     1    4050    포인트 2022-11-08 10:45:14  배송완료    N     11  2022
# 218600    17  161500   신용카드 2022-11-08 10:49:28  배송완료    N     11  2022
#
# [218601 rows x 12 columns]

# %%
df.drop(['주문일자'], axis=1, inplace=True)
df
# Out:
#                    주문번호    업체명                                  상품명    제조사  \
# 0       191213170236874     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 1       191216100347429     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 2       191216100347429     지니             eHBM셀파수학교실 삼색볼펜-1세트 50개입     HB
# 3       191216173241622     지니          eHBM셀파수학교실 회원용 리플렛-1세트 50권입     HB
# 4       191216173241622     지니              eHBM셀파수학교실-학습계통도(중등 5종)     HB
# ...                 ...    ...                                  ...    ...
# 218596  221108104041264  에이스디포               [스마트 HBE*초도] 입체 액자형 현판  에이스디포
# 218597  221108104041264  에이스디포                  [스마트 HBE*초도] 아크릴 사인     HB
# 218598  221108104536307  에이스디포                     [스마트 HBM] 아크릴 사인     HB
# 218599  221108104735216   다우기술                [스타벅스] 아이스 카페 아메리카노 T   스타벅스
# 218600  221108105148171   다우기술  [특별한 크리스마스] 2차-신세계 상품권 모바일 교환권-1만원권    신세계
#
#         주문수량    판매금액   결제방법  처리상태 초도상품  Month  Year
# 0          1    5000   신용카드  구매확정    N     12  2019
# 1          1    5000   신용카드  구매확정    N     12  2019
# 2          3   67500   신용카드  구매확정    N     12  2019
# 3          2   30000   신용카드  구매확정    N     12  2019
# 4          1     750   신용카드  구매확정    N     12  2019
# ...      ...     ...    ...   ...  ...    ...   ...
# 218596     1   35000   웰컴마일  결제완료    Y     11  2022
# 218597     1   26900   웰컴마일  결제완료    Y     11  2022
# 218598     1   26900  신 + 포  배송준비    N     11  2022
# 218599     1    4050    포인트  배송완료    N     11  2022
# 218600    17  161500   신용카드  배송완료    N     11  2022
#
# [218601 rows x 11 columns]

# %% [markdown]
# **datetime으로 데이터 타입이 되어있어서, 그냥 월과 년도만 필요하니까 월 년만 나눔**

# %%
#초도상품에 대한 뭔가 인사이트는 없을 거 같은데. 컬럼 그냥 삭제해도 될 거 같은데
df.drop(['초도상품'], axis=1, inplace=True)
df
# Out:
#                    주문번호    업체명                                  상품명    제조사  \
# 0       191213170236874     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 1       191216100347429     지니            eHBM셀파수학교실 비닐봉투-1세트 100장입     HB
# 2       191216100347429     지니             eHBM셀파수학교실 삼색볼펜-1세트 50개입     HB
# 3       191216173241622     지니          eHBM셀파수학교실 회원용 리플렛-1세트 50권입     HB
# 4       191216173241622     지니              eHBM셀파수학교실-학습계통도(중등 5종)     HB
# ...                 ...    ...                                  ...    ...
# 218596  221108104041264  에이스디포               [스마트 HBE*초도] 입체 액자형 현판  에이스디포
# 218597  221108104041264  에이스디포                  [스마트 HBE*초도] 아크릴 사인     HB
# 218598  221108104536307  에이스디포                     [스마트 HBM] 아크릴 사인     HB
# 218599  221108104735216   다우기술                [스타벅스] 아이스 카페 아메리카노 T   스타벅스
# 218600  221108105148171   다우기술  [특별한 크리스마스] 2차-신세계 상품권 모바일 교환권-1만원권    신세계
#
#         주문수량    판매금액   결제방법  처리상태  Month  Year
# 0          1    5000   신용카드  구매확정     12  2019
# 1          1    5000   신용카드  구매확정     12  2019
# 2          3   67500   신용카드  구매확정     12  2019
# 3          2   30000   신용카드  구매확정     12  2019
# 4          1     750   신용카드  구매확정     12  2019
# ...      ...     ...    ...   ...    ...   ...
# 218596     1   35000   웰컴마일  결제완료     11  2022
# 218597     1   26900   웰컴마일  결제완료     11  2022
# 218598     1   26900  신 + 포  배송준비     11  2022
# 218599     1    4050    포인트  배송완료     11  2022
# 218600    17  161500   신용카드  배송완료     11  2022
#
# [218601 rows x 10 columns]

# %%
monthly_total_price = df.groupby('Month')['판매금액'].sum()
pd.DataFrame(monthly_total_price)
# Out:
#              판매금액
# Month
# 1       820302715
# 2      1167621265
# 3      1383912487
# 4       755775808
# 5      1306188345
# 6       677740965
# 7       725453720
# 8      1020860565
# 9       885305480
# 10     1262633798
# 11      689992304
# 12      837385183

# %%
df['처리상태'].value_counts()
# Out:
# 구매확정       159291
# 미결제         49574
# 주문취소         6269
# 배송완료         1445
# 환불완료          785
# 배송준비          527
# 배송중           320
# 환불승인          163
# 상담취소          143
# 결제완료           28
# 부분환불           23
# 부분취소           16
# 시안확인요청          6
# 교환완료            4
# 후불반려            4
# 환불요청            2
# 상담형상품접수         1
# Name: 처리상태, dtype: int64

# %% [markdown]
# **-----------------전처리 일단 이 정도 완료--------------------------------**

# %% [markdown]
# **-----------------시각화 월별, 년별 매출액 시각화--------------------------------**

# %%
#월별 합계 추이 살펴보기
plt.plot(df.groupby('Month')['판매금액'].sum())
plt.grid(True)

# %%
month_price = df.groupby('Month')['판매금액'].sum().sort_values()
month_price.plot(kind='bar', color='gray', figsize=(10,10))
plt.title('Monthly_price')
plt.grid(True)

# %%
#년별 매출액
df.groupby('Year')['판매금액'].sum()
# Out:
# Year
# 2019       9350160
# 2020    1538470245
# 2021    3913382820
# 2022    6071969410
# Name: 판매금액, dtype: int64

# %%
#년별 매출액
plt.plot(df.groupby('Year')['판매금액'].sum())
plt.grid(True)
#매년 매출액이 증가함을 알 수 있다.

# %%
year_price = df.groupby('Year')['판매금액'].sum().sort_values()
year_price.plot(kind='bar', color='gray', figsize=(10,10))
plt.title('Year_price')
plt.grid(True)

# %% [markdown]
# -----------------매출 순수익--------------------------------

# %%
#일단 순수익은 only 구매확정으로만 보고
#할부 기간은 non값이 너무많기 때문에, 그냥 배제하고 total - 구매확정을 제외한 나머지를 빼는게 나을듯ㅠ

# %%
monthly_total_price
pd.DataFrame(monthly_total_price)
#total_price는 전부 monthly전부 합쳐서 가격매김
# Out:
#              판매금액
# Month
# 1       820302715
# 2      1167621265
# 3      1383912487
# 4       755775808
# 5      1306188345
# 6       677740965
# 7       725453720
# 8      1020860565
# 9       885305480
# 10     1262633798
# 11      689992304
# 12      837385183

# %%
#처리상태가 구매확정인거만 빼서, 월별 판매금액을 groupby
acc_df = df[df['처리상태'] == '구매확정']
sum_acc_df = acc_df.groupby('Month')['판매금액'].sum()
pd.DataFrame(sum_acc_df)
# Out:
#              판매금액
# Month
# 1       577639300
# 2       756443825
# 3       989788885
# 4       595245808
# 5      1044829970
# 6       487594235
# 7       504010990
# 8       686551760
# 9       655901140
# 10      895017703
# 11      395669874
# 12      575876348

# %%
income_price = monthly_total_price - sum_acc_df
pd.DataFrame(income_price)
# Out:
#             판매금액
# Month
# 1      242663415
# 2      411177440
# 3      394123602
# 4      160530000
# 5      261358375
# 6      190146730
# 7      221442730
# 8      334308805
# 9      229404340
# 10     367616095
# 11     294322430
# 12     261508835

# %%
#판매금액이 구매확정인것만 고려한 그래프
income_price.plot(kind='bar', color='gray', title='income_price')
plt.grid(True)
plt.figure(figsize=(12,12))

# %% [markdown]
# 2. 선택분석
#
# *  최대 매출 상품 3종류 집계
# *  주문 연도에 따른 해당 상품의
# 매출 증감 분석

# %%
#주문 연도에 따른 해당 상품의 매출 증감 분석

# %%
top3_selling = df.groupby('상품명')['판매금액'].sum().sort_values(ascending=False)[:3]
top3_selling
# Out:
# 상품명
# [스마트 HBE] 학습 전용 태블릿-일반결제       965844000
# [신세계] 신세계 상품권-4만원권             896793600
# [지사전용] 스마트 HBE-학습 전용 태블릿-후불    622908000
# Name: 판매금액, dtype: int64

# %%
#최대매출 3종류인 상품을 뽑아냈고,
#거기서 해당 top3_selling의 년도별 매출액 증감추이를 살펴야하는데,
# Out:
# Index(['[스마트 HBE] 학습 전용 태블릿-일반결제', '[신세계] 신세계 상품권-4만원권',
#        '[지사전용] 스마트 HBE-학습 전용 태블릿-후불'],
#       dtype='object', name='상품명')
